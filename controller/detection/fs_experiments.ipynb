# %%
# Data preprocessing & dataset creation
from log_reader import read_all_logs
from preprocessors.preprocessor import Preprocessor
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from scipy.sparse import csr_matrix

df = read_all_logs(version=2)
unique_syscalls = df['syscall'].unique().tolist()
print("Unique system calls: ", len(unique_syscalls))
df = Preprocessor.get(version=2).preprocess(df)

X_train, X_test, y_train, y_test = train_test_split(df['syscall'], df['malicious'], test_size=0.2, random_state=42)

features_dict = {}
ngrams = range(4,8)
vectorizers = [CountVectorizer, TfidfVectorizer]

for vec_class in vectorizers:
    features_dict[vec_class.__name__] = {}
    for ngram in ngrams:
        vectorizer = vec_class(ngram_range=(ngram, ngram), token_pattern=r'\b\w+\b')
        X_train_vec = csr_matrix(vectorizer.fit_transform(X_train))
        X_test_vec = csr_matrix(vectorizer.transform(X_test))
        features_dict[vectorizer.__class__.__name__][ngram] = X_train_vec, X_test_vec

print(features_dict['CountVectorizer'][6][0].shape)
# Out:
# Reading logs from ../logs/V1
# Reading logs from ../logs/V2-1
# Reading logs from ../logs/V2
# Classifying malicious_ransomwarePOC_10min_1.log as malicious, 13383 malicious entries found
# Classifying malicious_ransomwarePOC_10min.log as malicious, 14477 malicious entries found
# Classifying malicious_JavaRansomware_30min.log as malicious, 45982 malicious entries found
# Classifying malicious_RAASNet-AES_60min.log as malicious, 10348 malicious entries found
# Classifying malicious_ransim_20min.log as malicious, 23227 malicious entries found
# Classifying malicious_RAASNet-Crypto_20min.log as malicious, 20069 malicious entries found
# Classifying malicious_roar-ChaCha20_60min.log as malicious, 33968 malicious entries found
# Classifying malicious_roar-AES-CTR_60min.log as malicious, 71676 malicious entries found
# Classifying malicious_ransim-slow_60min.log as malicious, 23621 malicious entries found
# Classifying malicious_cry_20min.log as malicious, 8185 malicious entries found
# Classifying malicious_ransim-slow_30min.log as malicious, 8586 malicious entries found
# Classifying malicious_ransim_10min.log as malicious, 3221 malicious entries found
# Classifying malicious_roar-ChaCha20_60min.log as malicious, 32965 malicious entries found
# Classifying malicious_JavaRansomware_15min.log as malicious, 15232 malicious entries found
# Classifying malicious_cry_10min.log as malicious, 4776 malicious entries found
# Classifying malicious_roar-AES-CTR_60min.log as malicious, 47470 malicious entries found
# Classifying malicious_RAASNet-Crypto_15min.log as malicious, 10145 malicious entries found
# Classifying malicious_RAASNet-AES_30min.log as malicious, 4252 malicious entries found
# Unique system calls:  454
# (54555, 86880)

# %%
from sklearn.metrics import accuracy_score, f1_score
def get_test_metrics(y_true, y_pred):
    acc = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    return acc, f1

# %%
from sklearn.naive_bayes import MultinomialNB

def test_on_nb(X_train, y_train, X_test, y_test):
    clf = MultinomialNB()
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    return get_test_metrics(y_test, y_pred)

# %%
from models.V2.iforest import IForest

def test_on_iforest(X_train, y_train, X_test, y_test):
    clf = IForest(None)
    clf.fit_vectorized(X_train, y_train)
    y_pred = clf.instance.predict(X_test)
    y_pred = clf.pred_to_binary(y_pred)
    return get_test_metrics(y_test, y_pred)

# %%
from models.V2.lof import LOF

def test_on_lof(X_train, y_train, X_test, y_test):
    clf = LOF(None)
    clf.fit_vectorized(X_train, y_train)
    y_pred = clf.instance.predict(X_test)
    y_pred = clf.pred_to_binary(y_pred)
    return get_test_metrics(y_test, y_pred)

# %%
from sklearn.ensemble import RandomForestClassifier as RandomForest

def test_on_rf(X_train, y_train, X_test, y_test):
    clf = RandomForest()
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    return get_test_metrics(y_test, y_pred)

# %%
import concurrent.futures

def parallel_test(model, test_func, X_train, y_train, X_test, y_test, vec_name, ngram, selection):
    acc, f1 = test_func(X_train, y_train, X_test, y_test)
    return {'Vectorizer': vec_name, 'Ngram': ngram, 'Model': model, 'Accuracy': acc, 'F1': f1, 'Selection': selection, 'Features': X_train.shape[1]}

def get_test_results(features_dict, selection, max_workers=4):
    results = []
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = []
        for vec_name, vec_dict in features_dict.items():
            for ngram, (X_train, X_test) in vec_dict.items():
                for model, test_func in [('NB', test_on_nb), ('IForest', test_on_iforest), ('LOF', test_on_lof), ('RF', test_on_rf)]:
                    future = executor.submit(parallel_test, model, test_func, X_train, y_train, X_test, y_test, vec_name, ngram, selection)
                    futures.append(future)
        for future in concurrent.futures.as_completed(futures):
            results.append(future.result())
        concurrent.futures.wait(futures)
    return results

# %%
# Get results with no feature selection
import pandas as pd

results_df = pd.DataFrame(get_test_results(features_dict, 'None'))
results_df
# Out:
#          Vectorizer  Ngram    Model  Accuracy        F1 Selection  Features
# 0   CountVectorizer      4       NB  0.990688  0.948479      None     54606
# 1   CountVectorizer      5       NB  0.988416  0.934548      None     72233
# 2   CountVectorizer      4  IForest  0.891121  0.148997      None     54606
# 3   CountVectorizer      5  IForest  0.891121  0.131071      None     72233
# 4   CountVectorizer      4       RF  0.989735  0.942149      None     54606
# 5   CountVectorizer      6       NB  0.986363  0.921651      None     86880
# 6   CountVectorizer      6  IForest  0.894934  0.133091      None     86880
# 7   CountVectorizer      5       RF  0.987389  0.927792      None     72233
# 8   CountVectorizer      4      LOF  0.885329  0.093859      None     54606
# 9   CountVectorizer      7       NB  0.984750  0.911263      None     99384
# 10  CountVectorizer      5      LOF  0.891121  0.090631      None     72233
# 11  CountVectorizer      7  IForest  0.898600  0.146823      None     99384
# 12  CountVectorizer      6       RF  0.984310  0.908390      None     86880
# 13  TfidfVectorizer      4       NB  0.987389  0.927487      None     54606
# 14  TfidfVectorizer      4  IForest  0.894054  0.158416      None     54606
# 15  CountVectorizer      6      LOF  0.894860  0.100376      None     86880
# 16  CountVectorizer      7       RF  0.983063  0.900216      None     99384
# 17  TfidfVectorizer      5       NB  0.987609  0.929495      None     72233
# 18  TfidfVectorizer      4       RF  0.990102  0.944146      None     54606
# 19  TfidfVectorizer      5  IForest  0.894200  0.138507      None     72233
# 20  CountVectorizer      7      LOF  0.896693  0.091554      None     99384
# 21  TfidfVectorizer      6       NB  0.984970  0.912877      None     86880
# 22  TfidfVectorizer      6  IForest  0.895740  0.149522      None     86880
# 23  TfidfVectorizer      4      LOF  0.890241  0.049524      None     54606
# 24  TfidfVectorizer      5       RF  0.987316  0.927219      None     72233
# 25  TfidfVectorizer      7       NB  0.983210  0.901421      None     99384
# 26  TfidfVectorizer      7  IForest  0.897646  0.129676      None     99384
# 27  TfidfVectorizer      5      LOF  0.889068  0.049026      None     72233
# 28  TfidfVectorizer      6      LOF  0.893247  0.061856      None     86880
# 29  TfidfVectorizer      6       RF  0.984456  0.909324      None     86880
# 30  TfidfVectorizer      7      LOF  0.893541  0.071611      None     99384
# 31  TfidfVectorizer      7       RF  0.982917  0.899178      None     99384

# %%
# remove features with low variance
from sklearn.feature_selection import VarianceThreshold
threshold = 0.0001
results = []
features_varthresh_dict = {}
for vec_name, vec_dict in features_dict.items():
    features_varthresh_dict[vec_name] = {}
    for ngram, (X_train, X_test) in vec_dict.items():
        selector = VarianceThreshold(threshold=threshold)
        X_train_reduced = selector.fit_transform(X_train)
        X_test_reduced = selector.transform(X_test)
        features_varthresh_dict[vec_name][ngram] = X_train_reduced, X_test_reduced

results_var_df = pd.DataFrame(get_test_results(features_varthresh_dict, 'VarianceThreshold'))
results_df = pd.concat([results_df, results_var_df])
results_var_df
# Out:
#          Vectorizer  Ngram    Model  Accuracy        F1          Selection  \
# 0   CountVectorizer      4       NB  0.990322  0.946385  VarianceThreshold
# 1   CountVectorizer      5       NB  0.987902  0.931450  VarianceThreshold
# 2   CountVectorizer      4  IForest  0.889875  0.213613  VarianceThreshold
# 3   CountVectorizer      5  IForest  0.891854  0.214172  VarianceThreshold
# 4   CountVectorizer      4       RF  0.989735  0.942292  VarianceThreshold
# 5   CountVectorizer      6       NB  0.985996  0.919375  VarianceThreshold
# 6   CountVectorizer      6  IForest  0.889215  0.200952  VarianceThreshold
# 7   CountVectorizer      5       RF  0.987536  0.928691  VarianceThreshold
# 8   CountVectorizer      6       RF  0.984750  0.911263  VarianceThreshold
# 9   CountVectorizer      7       NB  0.984090  0.907146  VarianceThreshold
# 10  CountVectorizer      7  IForest  0.886942  0.189274  VarianceThreshold
# 11  CountVectorizer      4      LOF  0.880490  0.110262  VarianceThreshold
# 12  CountVectorizer      5      LOF  0.883862  0.115084  VarianceThreshold
# 13  TfidfVectorizer      4       NB  0.982477  0.897820  VarianceThreshold
# 14  TfidfVectorizer      4  IForest  0.859227  0.035176  VarianceThreshold
# 15  CountVectorizer      7       RF  0.983283  0.901554  VarianceThreshold
# 16  CountVectorizer      6      LOF  0.875431  0.119233  VarianceThreshold
# 17  TfidfVectorizer      5       NB  0.979911  0.880662  VarianceThreshold
# 18  TfidfVectorizer      5  IForest  0.860840  0.046231  VarianceThreshold
# 19  TfidfVectorizer      4       RF  0.985703  0.918444  VarianceThreshold
# 20  TfidfVectorizer      5       RF  0.981670  0.892241  VarianceThreshold
# 21  TfidfVectorizer      6       NB  0.976685  0.857909  VarianceThreshold
# 22  CountVectorizer      7      LOF  0.877264  0.124477  VarianceThreshold
# 23  TfidfVectorizer      6  IForest  0.854242  0.008973  VarianceThreshold
# 24  TfidfVectorizer      6       RF  0.978664  0.871296  VarianceThreshold
# 25  TfidfVectorizer      7       NB  0.973898  0.837887  VarianceThreshold
# 26  TfidfVectorizer      7  IForest  0.853875  0.001003  VarianceThreshold
# 27  TfidfVectorizer      4      LOF  0.855855  0.051158  VarianceThreshold
# 28  TfidfVectorizer      7       RF  0.976831  0.859054  VarianceThreshold
# 29  TfidfVectorizer      5      LOF  0.860034  0.045977  VarianceThreshold
# 30  TfidfVectorizer      6      LOF  0.856441  0.052275  VarianceThreshold
# 31  TfidfVectorizer      7      LOF  0.859007  0.063322  VarianceThreshold
#
#     Features
# 0       5361
# 1       5670
# 2       5361
# 3       5670
# 4       5361
# 5       5615
# 6       5615
# 7       5670
# 8       5615
# 9       5470
# 10      5470
# 11      5361
# 12      5670
# 13       485
# 14       485
# 15      5470
# 16      5615
# 17       474
# 18       474
# 19       485
# 20       474
# 21       449
# 22      5470
# 23       449
# 24       449
# 25       407
# 26       407
# 27       485
# 28       407
# 29       474
# 30       449
# 31       407

# %%
# RFE feature selection
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

results = []
features_rfe_dict = {}
for vec_name, vec_dict in features_dict.items():
    features_rfe_dict[vec_name] = {}
    for ngram, (X_train_rfe, X_test_rfe) in vec_dict.items():
        print(vec_name, ngram)
        # Initialize the estimator and RFE
        estimator = LogisticRegression(solver='lbfgs', max_iter=1000)
        selector = RFE(estimator, n_features_to_select=int(X_train_rfe.shape[1]/2), step=1000)

        X_train_reduced = selector.fit_transform(X_train_rfe, y_train)
        X_test_reduced = selector.transform(X_test_rfe)
        features_rfe_dict[vec_name][ngram] = X_train_reduced, X_test_reduced

results_rfe_df = pd.DataFrame(get_test_results(features_rfe_dict, 'RFE'))
results_df = pd.concat([results_df, results_rfe_df])
results_rfe_df
# Out:
# CountVectorizer 4
# CountVectorizer 5
# CountVectorizer 6
# CountVectorizer 7
# TfidfVectorizer 4
# TfidfVectorizer 5
# TfidfVectorizer 6
# TfidfVectorizer 7
#          Vectorizer  Ngram    Model  Accuracy        F1 Selection  Features
# 0   CountVectorizer      4       NB  0.990835  0.949249       RFE     27303
# 1   CountVectorizer      5       NB  0.988269  0.933610       RFE     36116
# 2   CountVectorizer      4  IForest  0.885769  0.132517       RFE     27303
# 3   CountVectorizer      5  IForest  0.890828  0.145726       RFE     36116
# 4   CountVectorizer      4       RF  0.990029  0.943848       RFE     27303
# 5   CountVectorizer      6       NB  0.986363  0.921651       RFE     43440
# 6   CountVectorizer      6  IForest  0.895080  0.155752       RFE     43440
# 7   CountVectorizer      5       RF  0.987536  0.928511       RFE     36116
# 8   CountVectorizer      5      LOF  0.893467  0.086738       RFE     36116
# 9   CountVectorizer      7       NB  0.984676  0.910798       RFE     49692
# 10  CountVectorizer      7  IForest  0.892881  0.168469       RFE     49692
# 11  CountVectorizer      4      LOF  0.889581  0.088378       RFE     27303
# 12  CountVectorizer      6       RF  0.984236  0.908002       RFE     43440
# 13  TfidfVectorizer      4       NB  0.988855  0.936614       RFE     27303
# 14  TfidfVectorizer      4  IForest  0.889435  0.179543       RFE     27303
# 15  CountVectorizer      6      LOF  0.896400  0.084251       RFE     43440
# 16  CountVectorizer      7       RF  0.982843  0.898964       RFE     49692
# 17  TfidfVectorizer      5       NB  0.987829  0.930891       RFE     36116
# 18  TfidfVectorizer      5  IForest  0.893687  0.187220       RFE     36116
# 19  TfidfVectorizer      4       RF  0.990102  0.944146       RFE     27303
# 20  CountVectorizer      7      LOF  0.896400  0.088975       RFE     49692
# 21  TfidfVectorizer      6       NB  0.985190  0.914334       RFE     43440
# 22  TfidfVectorizer      6  IForest  0.895154  0.201117       RFE     43440
# 23  TfidfVectorizer      4      LOF  0.896620  0.073587       RFE     27303
# 24  TfidfVectorizer      5       RF  0.987096  0.925988       RFE     36116
# 25  TfidfVectorizer      7       NB  0.983430  0.902921       RFE     49692
# 26  TfidfVectorizer      7  IForest  0.897280  0.201709       RFE     49692
# 27  TfidfVectorizer      5      LOF  0.899846  0.092961       RFE     36116
# 28  TfidfVectorizer      6       RF  0.984456  0.909247       RFE     43440
# 29  TfidfVectorizer      6      LOF  0.903439  0.103472       RFE     43440
# 30  TfidfVectorizer      7      LOF  0.906665  0.105411       RFE     49692
# 31  TfidfVectorizer      7       RF  0.982917  0.899352       RFE     49692

# %%
results_df.sort_values(by='F1', ascending=False, inplace=True)
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(results_df)
# Out:
#          Vectorizer  Ngram    Model  Accuracy        F1          Selection  \
# 0   CountVectorizer      4       NB  0.990835  0.949249                RFE
# 0   CountVectorizer      4       NB  0.990688  0.948479               None
# 0   CountVectorizer      4       NB  0.990322  0.946385  VarianceThreshold
# 18  TfidfVectorizer      4       RF  0.990102  0.944146               None
# 19  TfidfVectorizer      4       RF  0.990102  0.944146                RFE
# 4   CountVectorizer      4       RF  0.990029  0.943848                RFE
# 4   CountVectorizer      4       RF  0.989735  0.942292  VarianceThreshold
# 4   CountVectorizer      4       RF  0.989735  0.942149               None
# 13  TfidfVectorizer      4       NB  0.988855  0.936614                RFE
# 1   CountVectorizer      5       NB  0.988416  0.934548               None
# 1   CountVectorizer      5       NB  0.988269  0.933610                RFE
# 1   CountVectorizer      5       NB  0.987902  0.931450  VarianceThreshold
# 17  TfidfVectorizer      5       NB  0.987829  0.930891                RFE
# 17  TfidfVectorizer      5       NB  0.987609  0.929495               None
# 7   CountVectorizer      5       RF  0.987536  0.928691  VarianceThreshold
# 7   CountVectorizer      5       RF  0.987536  0.928511                RFE
# 7   CountVectorizer      5       RF  0.987389  0.927792               None
# 13  TfidfVectorizer      4       NB  0.987389  0.927487               None
# 24  TfidfVectorizer      5       RF  0.987316  0.927219               None
# 24  TfidfVectorizer      5       RF  0.987096  0.925988                RFE
# 5   CountVectorizer      6       NB  0.986363  0.921651               None
# 5   CountVectorizer      6       NB  0.986363  0.921651                RFE
# 5   CountVectorizer      6       NB  0.985996  0.919375  VarianceThreshold
# 19  TfidfVectorizer      4       RF  0.985703  0.918444  VarianceThreshold
# 21  TfidfVectorizer      6       NB  0.985190  0.914334                RFE
# 21  TfidfVectorizer      6       NB  0.984970  0.912877               None
# 9   CountVectorizer      7       NB  0.984750  0.911263               None
# 8   CountVectorizer      6       RF  0.984750  0.911263  VarianceThreshold
# 9   CountVectorizer      7       NB  0.984676  0.910798                RFE
# 29  TfidfVectorizer      6       RF  0.984456  0.909324               None
# 28  TfidfVectorizer      6       RF  0.984456  0.909247                RFE
# 12  CountVectorizer      6       RF  0.984310  0.908390               None
# 12  CountVectorizer      6       RF  0.984236  0.908002                RFE
# 9   CountVectorizer      7       NB  0.984090  0.907146  VarianceThreshold
# 25  TfidfVectorizer      7       NB  0.983430  0.902921                RFE
# 15  CountVectorizer      7       RF  0.983283  0.901554  VarianceThreshold
# 25  TfidfVectorizer      7       NB  0.983210  0.901421               None
# 16  CountVectorizer      7       RF  0.983063  0.900216               None
# 31  TfidfVectorizer      7       RF  0.982917  0.899352                RFE
# 31  TfidfVectorizer      7       RF  0.982917  0.899178               None
# 16  CountVectorizer      7       RF  0.982843  0.898964                RFE
# 13  TfidfVectorizer      4       NB  0.982477  0.897820  VarianceThreshold
# 20  TfidfVectorizer      5       RF  0.981670  0.892241  VarianceThreshold
# 17  TfidfVectorizer      5       NB  0.979911  0.880662  VarianceThreshold
# 24  TfidfVectorizer      6       RF  0.978664  0.871296  VarianceThreshold
# 28  TfidfVectorizer      7       RF  0.976831  0.859054  VarianceThreshold
# 21  TfidfVectorizer      6       NB  0.976685  0.857909  VarianceThreshold
# 25  TfidfVectorizer      7       NB  0.973898  0.837887  VarianceThreshold
# 3   CountVectorizer      5  IForest  0.891854  0.214172  VarianceThreshold
# 2   CountVectorizer      4  IForest  0.889875  0.213613  VarianceThreshold
# 26  TfidfVectorizer      7  IForest  0.897280  0.201709                RFE
# 22  TfidfVectorizer      6  IForest  0.895154  0.201117                RFE
# 6   CountVectorizer      6  IForest  0.889215  0.200952  VarianceThreshold
# 10  CountVectorizer      7  IForest  0.886942  0.189274  VarianceThreshold
# 18  TfidfVectorizer      5  IForest  0.893687  0.187220                RFE
# 14  TfidfVectorizer      4  IForest  0.889435  0.179543                RFE
# 10  CountVectorizer      7  IForest  0.892881  0.168469                RFE
# 14  TfidfVectorizer      4  IForest  0.894054  0.158416               None
# 6   CountVectorizer      6  IForest  0.895080  0.155752                RFE
# 22  TfidfVectorizer      6  IForest  0.895740  0.149522               None
# 2   CountVectorizer      4  IForest  0.891121  0.148997               None
# 11  CountVectorizer      7  IForest  0.898600  0.146823               None
# 3   CountVectorizer      5  IForest  0.890828  0.145726                RFE
# 19  TfidfVectorizer      5  IForest  0.894200  0.138507               None
# 6   CountVectorizer      6  IForest  0.894934  0.133091               None
# 2   CountVectorizer      4  IForest  0.885769  0.132517                RFE
# 3   CountVectorizer      5  IForest  0.891121  0.131071               None
# 26  TfidfVectorizer      7  IForest  0.897646  0.129676               None
# 22  CountVectorizer      7      LOF  0.877264  0.124477  VarianceThreshold
# 16  CountVectorizer      6      LOF  0.875431  0.119233  VarianceThreshold
# 12  CountVectorizer      5      LOF  0.883862  0.115084  VarianceThreshold
# 11  CountVectorizer      4      LOF  0.880490  0.110262  VarianceThreshold
# 30  TfidfVectorizer      7      LOF  0.906665  0.105411                RFE
# 29  TfidfVectorizer      6      LOF  0.903439  0.103472                RFE
# 15  CountVectorizer      6      LOF  0.894860  0.100376               None
# 8   CountVectorizer      4      LOF  0.885329  0.093859               None
# 27  TfidfVectorizer      5      LOF  0.899846  0.092961                RFE
# 20  CountVectorizer      7      LOF  0.896693  0.091554               None
# 10  CountVectorizer      5      LOF  0.891121  0.090631               None
# 20  CountVectorizer      7      LOF  0.896400  0.088975                RFE
# 11  CountVectorizer      4      LOF  0.889581  0.088378                RFE
# 8   CountVectorizer      5      LOF  0.893467  0.086738                RFE
# 15  CountVectorizer      6      LOF  0.896400  0.084251                RFE
# 23  TfidfVectorizer      4      LOF  0.896620  0.073587                RFE
# 30  TfidfVectorizer      7      LOF  0.893541  0.071611               None
# 31  TfidfVectorizer      7      LOF  0.859007  0.063322  VarianceThreshold
# 28  TfidfVectorizer      6      LOF  0.893247  0.061856               None
# 30  TfidfVectorizer      6      LOF  0.856441  0.052275  VarianceThreshold
# 27  TfidfVectorizer      4      LOF  0.855855  0.051158  VarianceThreshold
# 23  TfidfVectorizer      4      LOF  0.890241  0.049524               None
# 27  TfidfVectorizer      5      LOF  0.889068  0.049026               None
# 18  TfidfVectorizer      5  IForest  0.860840  0.046231  VarianceThreshold
# 29  TfidfVectorizer      5      LOF  0.860034  0.045977  VarianceThreshold
# 14  TfidfVectorizer      4  IForest  0.859227  0.035176  VarianceThreshold
# 23  TfidfVectorizer      6  IForest  0.854242  0.008973  VarianceThreshold
# 26  TfidfVectorizer      7  IForest  0.853875  0.001003  VarianceThreshold
#
#     Features
# 0      27303
# 0      54606
# 0       5361
# 18     54606
# 19     27303
# 4      27303
# 4       5361
# 4      54606
# 13     27303
# 1      72233
# 1      36116
# 1       5670
# 17     36116
# 17     72233
# 7       5670
# 7      36116
# 7      72233
# 13     54606
# 24     72233
# 24     36116
# 5      86880
# 5      43440
# 5       5615
# 19       485
# 21     43440
# 21     86880
# 9      99384
# 8       5615
# 9      49692
# 29     86880
# 28     43440
# 12     86880
# 12     43440
# 9       5470
# 25     49692
# 15      5470
# 25     99384
# 16     99384
# 31     49692
# 31     99384
# 16     49692
# 13       485
# 20       474
# 17       474
# 24       449
# 28       407
# 21       449
# 25       407
# 3       5670
# 2       5361
# 26     49692
# 22     43440
# 6       5615
# 10      5470
# 18     36116
# 14     27303
# 10     49692
# 14     54606
# 6      43440
# 22     86880
# 2      54606
# 11     99384
# 3      36116
# 19     72233
# 6      86880
# 2      27303
# 3      72233
# 26     99384
# 22      5470
# 16      5615
# 12      5670
# 11      5361
# 30     49692
# 29     43440
# 15     86880
# 8      54606
# 27     36116
# 20     99384
# 10     72233
# 20     49692
# 11     27303
# 8      36116
# 15     43440
# 23     27303
# 30     99384
# 31       407
# 28     86880
# 30       449
# 27       485
# 23     54606
# 27     72233
# 18       474
# 29       474
# 14       485
# 23       449
# 26       407

# %%
None_df = results_df[results_df['Selection'] == 'None'].drop(columns=['Selection', 'Accuracy'])
VarianceThreshold_df = results_df[results_df['Selection'] == 'VarianceThreshold'].drop(columns=['Selection', 'Accuracy'])
RFE_df = results_df[results_df['Selection'] == 'RFE'].drop(columns=['Selection', 'Accuracy'])

vt_merge = None_df.merge(VarianceThreshold_df, on=['Vectorizer', 'Ngram', 'Model'], suffixes=(None, '_VT'))
merged_df = vt_merge.merge(RFE_df, on=['Vectorizer', 'Ngram', 'Model'], suffixes=(None,'_RFE'))
merged_df['F1_diff_VT'] = merged_df['F1_VT'] - merged_df['F1']
merged_df['F1_diff_RFE'] = merged_df['F1_RFE'] - merged_df['F1']
merged_df.drop(columns=['F1', 'F1_VT', 'F1_RFE'], inplace=True)
merged_df = merged_df.sort_values(by=['Model', 'Vectorizer', 'Ngram'])
display(merged_df[merged_df['Model'] != 'IForest'].groupby(['Vectorizer', 'Ngram']).agg({'F1_diff_VT': 'mean', 'F1_diff_RFE': 'mean'}))
merged_df
# Out:
#                        F1_diff_VT  F1_diff_RFE
# Vectorizer      Ngram
# CountVectorizer 4        0.004818    -0.001004
#                 5        0.007418    -0.001371
#                 6        0.006484    -0.005505
#                 7        0.010048    -0.001432
# TfidfVectorizer 4       -0.017912     0.011063
#                 5       -0.028953     0.014700
#                 6       -0.034192     0.014332
#                 7       -0.037315     0.011825
#          Vectorizer  Ngram    Model  Features  Features_VT  Features_RFE  \
# 18  CountVectorizer      4  IForest     54606         5361         27303
# 22  CountVectorizer      5  IForest     72233         5670         36116
# 21  CountVectorizer      6  IForest     86880         5615         43440
# 19  CountVectorizer      7  IForest     99384         5470         49692
# 16  TfidfVectorizer      4  IForest     54606          485         27303
# 20  TfidfVectorizer      5  IForest     72233          474         36116
# 17  TfidfVectorizer      6  IForest     86880          449         43440
# 23  TfidfVectorizer      7  IForest     99384          407         49692
# 25  CountVectorizer      4      LOF     54606         5361         27303
# 27  CountVectorizer      5      LOF     72233         5670         36116
# 24  CountVectorizer      6      LOF     86880         5615         43440
# 26  CountVectorizer      7      LOF     99384         5470         49692
# 30  TfidfVectorizer      4      LOF     54606          485         27303
# 31  TfidfVectorizer      5      LOF     72233          474         36116
# 29  TfidfVectorizer      6      LOF     86880          449         43440
# 28  TfidfVectorizer      7      LOF     99384          407         49692
# 0   CountVectorizer      4       NB     54606         5361         27303
# 3   CountVectorizer      5       NB     72233         5670         36116
# 8   CountVectorizer      6       NB     86880         5615         43440
# 10  CountVectorizer      7       NB     99384         5470         49692
# 6   TfidfVectorizer      4       NB     54606          485         27303
# 4   TfidfVectorizer      5       NB     72233          474         36116
# 9   TfidfVectorizer      6       NB     86880          449         43440
# 13  TfidfVectorizer      7       NB     99384          407         49692
# 2   CountVectorizer      4       RF     54606         5361         27303
# 5   CountVectorizer      5       RF     72233         5670         36116
# 12  CountVectorizer      6       RF     86880         5615         43440
# 14  CountVectorizer      7       RF     99384         5470         49692
# 1   TfidfVectorizer      4       RF     54606          485         27303
# 7   TfidfVectorizer      5       RF     72233          474         36116
# 11  TfidfVectorizer      6       RF     86880          449         43440
# 15  TfidfVectorizer      7       RF     99384          407         49692
#
#     F1_diff_VT  F1_diff_RFE
# 18    0.064615    -0.016480
# 22    0.083101     0.014655
# 21    0.067861     0.022661
# 19    0.042451     0.021646
# 16   -0.123240     0.021127
# 20   -0.092276     0.048712
# 17   -0.140548     0.051596
# 23   -0.128673     0.072034
# 25    0.016403    -0.005481
# 27    0.024453    -0.003893
# 24    0.018856    -0.016125
# 26    0.032923    -0.002579
# 30    0.001634     0.024064
# 31   -0.003049     0.043936
# 29   -0.009581     0.041616
# 28   -0.008289     0.033800
# 0    -0.002094     0.000770
# 3    -0.003099    -0.000939
# 8    -0.002276     0.000000
# 10   -0.004117    -0.000465
# 6    -0.029668     0.009126
# 4    -0.048833     0.001396
# 9    -0.054968     0.001457
# 13   -0.063534     0.001500
# 2     0.000143     0.001699
# 5     0.000900     0.000720
# 12    0.002872    -0.000389
# 14    0.001338    -0.001252
# 1    -0.025701     0.000000
# 7    -0.034978    -0.001231
# 11   -0.038028    -0.000078
# 15   -0.040123     0.000174

# %%
# show best performing model per model
model_score = results_df.groupby('Model').apply(lambda x: x.nlargest(1, 'F1')).reset_index(drop=True)
model_score.sort_values('F1', ascending=False, inplace=True)
model_score
# Out:
# /var/folders/qm/bgf8w3t57rs0n48ykj9024nr0000gn/T/ipykernel_37960/1494306661.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   model_score = results_df.groupby('Model').apply(lambda x: x.nlargest(1, 'F1')).reset_index(drop=True)
#         Vectorizer  Ngram    Model  Accuracy        F1          Selection  \
# 2  CountVectorizer      4       NB  0.990835  0.949249                RFE
# 3  TfidfVectorizer      4       RF  0.990102  0.944146               None
# 0  CountVectorizer      5  IForest  0.891854  0.214172  VarianceThreshold
# 1  CountVectorizer      7      LOF  0.877264  0.124477  VarianceThreshold
#
#    Features
# 2     27303
# 3     54606
# 0      5670
# 1      5470

# %%
# Effect of feature selection on best performing models from V2
from log_reader import read_all_logs
from preprocessors.preprocessor import Preprocessor
from train_models import train_test_split_df
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from scipy.sparse import csr_matrix
from models.V2.iforest import IForest
from models.V2.lof import LOF
from models.V2.rf import RF
from models.V2.nb import NB
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score


df = read_all_logs(version=2)
unique_syscalls = df['syscall'].unique().tolist()
print("Unique system calls: ", len(unique_syscalls))
df = Preprocessor.get(version=2).preprocess(df)

X_train, X_test, y_train, y_test = train_test_split_df(df=df)

token_pattern = r'\b\w+\b'

# Best V2 models:
best_models = [
    (NB, CountVectorizer, 2, False),
    (IForest, TfidfVectorizer, 2, True),
    (LOF, TfidfVectorizer, 2, True),
    (RF, CountVectorizer, 1, False)
]
best_models_results = []
for model_class, vectorizer_class, ngram, requires_to_binary in best_models:
    # RFE
    props = [model_class.__name__, vectorizer_class.__name__, ngram]
    model = model_class(vectorizer_class(ngram_range=(ngram, ngram), token_pattern=token_pattern))
    X_train_rfe = csr_matrix(model.vectorizer.fit_transform(X_train))
    X_test_rfe = csr_matrix(model.vectorizer.transform(X_test))
    estimator = LogisticRegression(solver='lbfgs', max_iter=1000)
    selector = RFE(estimator, n_features_to_select=int(X_train_rfe.shape[1]/2), step=1000)
    X_train_reduced = selector.fit_transform(X_train_rfe, y_train)
    X_test_reduced = selector.transform(X_test_rfe)
    model.fit_vectorized(X_train_reduced, y_train)
    y_pred = model.instance.predict(X_test_reduced)
    if requires_to_binary:
        y_pred = model.pred_to_binary(y_pred)
    f1 = f1_score(y_test, y_pred)
    props.append(f1)
    # VT
    model = model_class(vectorizer_class(ngram_range=(ngram, ngram), token_pattern=token_pattern))
    selector = VarianceThreshold(threshold=0.0001)
    X_train_varthresh = csr_matrix(model.vectorizer.fit_transform(X_train))
    X_test_varthresh = csr_matrix(model.vectorizer.transform(X_test))
    X_train_reduced = selector.fit_transform(X_train_varthresh)
    X_test_reduced = selector.transform(X_test_varthresh)
    model.fit_vectorized(X_train_reduced, y_train)
    y_pred = model.instance.predict(X_test_reduced)
    if requires_to_binary:
        y_pred = model.pred_to_binary(y_pred)
    f1 = f1_score(y_test, y_pred)
    props.append(f1)
    best_models_results.append(props)

best_models_results_df = pd.DataFrame(best_models_results, columns=['Model', 'Vectorizer', 'Ngram', 'RFE F1', 'VT F1'])
best_models_results_df
# Out:
# Reading logs from ../logs/V1
# Reading logs from ../logs/V2-1
# Reading logs from ../logs/V2
# Classifying malicious_ransomwarePOC_10min_1.log as malicious, 13383 malicious entries found
# Classifying malicious_ransomwarePOC_10min.log as malicious, 14477 malicious entries found
# Classifying malicious_JavaRansomware_30min.log as malicious, 45982 malicious entries found
# Classifying malicious_RAASNet-AES_60min.log as malicious, 10348 malicious entries found
# Classifying malicious_ransim_20min.log as malicious, 23227 malicious entries found
# Classifying malicious_RAASNet-Crypto_20min.log as malicious, 20069 malicious entries found
# Classifying malicious_roar-ChaCha20_60min.log as malicious, 33968 malicious entries found
# Classifying malicious_roar-AES-CTR_60min.log as malicious, 71676 malicious entries found
# Classifying malicious_ransim-slow_60min.log as malicious, 23621 malicious entries found
# Classifying malicious_cry_20min.log as malicious, 8185 malicious entries found
# Classifying malicious_ransim-slow_30min.log as malicious, 8586 malicious entries found
# Classifying malicious_ransim_10min.log as malicious, 3221 malicious entries found
# Classifying malicious_roar-ChaCha20_60min.log as malicious, 32965 malicious entries found
# Classifying malicious_JavaRansomware_15min.log as malicious, 15232 malicious entries found
# Classifying malicious_cry_10min.log as malicious, 4776 malicious entries found
# Classifying malicious_roar-AES-CTR_60min.log as malicious, 47470 malicious entries found
# Classifying malicious_RAASNet-Crypto_15min.log as malicious, 10145 malicious entries found
# Classifying malicious_RAASNet-AES_30min.log as malicious, 4252 malicious entries found
# Unique system calls:  454
#      Model       Vectorizer  Ngram    RFE F1     VT F1
# 0       NB  CountVectorizer      2  0.958301  0.956351
# 1  IForest  TfidfVectorizer      2  0.134677  0.109351
# 2      LOF  TfidfVectorizer      2  0.038982  0.018957
# 3       RF  CountVectorizer      1  0.945528  0.971452
