# %%
# SMOTE oversampling
from models.V2.nb import NB
from models.V2.rf import RF
from imblearn.over_sampling import SMOTE, RandomOverSampler
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from concurrent import futures as cf
from train_models import train_eval_model, to_model_properties, get_instantiated_models

def smote(X_train, y_train):
        smote = SMOTE(random_state=42)
        X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)
        return X_train_resampled, y_train_resampled

def random_oversample(X_train, y_train):
    ros = RandomOverSampler(random_state=42)
    X_train_resampled, y_train_resampled = ros.fit_resample(X_train, y_train)
    return X_train_resampled, y_train_resampled

class NB_SMOTE(NB):
    def fit_vectorized(self, X_train, y_train=None):
        X_train_resampled, y_train_resampled = smote(X_train, y_train)
        super().fit_vectorized(X_train_resampled, y_train_resampled)

    def get_model_type(self):
        return super().get_model_type() + '_SMOTE'
    
class RF_SMOTE(RF):
    def fit_vectorized(self, X_train, y_train):
        X_train_resampled, y_train_resampled = smote(X_train, y_train)
        super().fit_vectorized(X_train_resampled, y_train_resampled)

    def get_model_type(self):
        return super().get_model_type() + '_SMOTE'

class NB_ROS(NB):
    def fit_vectorized(self, X_train, y_train=None):
        X_train_resampled, y_train_resampled = random_oversample(X_train, y_train)
        super().fit_vectorized(X_train_resampled, y_train_resampled)

    def get_model_type(self):
        return super().get_model_type() + '_ROS'

class RF_ROS(RF):
    def fit_vectorized(self, X_train, y_train):
        X_train_resampled, y_train_resampled = random_oversample(X_train, y_train)
        super().fit_vectorized(X_train_resampled, y_train_resampled)

    def get_model_type(self):
        return super().get_model_type() + '_ROS'


def get_instantiated_oversampled_models():
    ngrams = range(1, 6)
    vectorizers = [CountVectorizer, TfidfVectorizer]
    models = [NB_SMOTE, RF_SMOTE, NB_ROS, RF_ROS]
    instantiated_models = []
    token_pattern = r'\b\w+\b'
    for vectorizer in vectorizers:
        for ngram in ngrams:
            for model in models:
                instantiated_models.append(model(vectorizer(ngram_range=(ngram, ngram), token_pattern=token_pattern)))
    return instantiated_models

def get_instantiated_normal_models():
    models = get_instantiated_models(version=2)
    models = [model for model in models if model.get_model_name() in ['NB', 'RF']]
    return models

def train_eval_models(models, X_train, X_test, y_train, y_test):
    scores = []
    with cf.ThreadPoolExecutor(max_workers=4) as executor:
        futures = [executor.submit(train_eval_model, model, X_train, X_test, y_train, y_test) for model in models]
        for future in cf.as_completed(futures):
            model, model_scores = future.result()
            row = model_scores | to_model_properties(model)
            scores.append(row)
        cf.wait(futures)
    return scores

# %%
from train_models import train_test_split_df
from log_reader import read_all_logs
from preprocessors.preprocessor import Preprocessor
import pandas as pd

df = read_all_logs(version=2)
df = Preprocessor.get(version=2).preprocess(df)
X_train, X_test, y_train, y_test = train_test_split_df(df)

scores_os = train_eval_models(get_instantiated_oversampled_models(), X_train, X_test, y_train, y_test)
scores = train_eval_models(get_instantiated_normal_models(), X_train, X_test,y_train, y_test)

scores_os_df = pd.DataFrame(scores_os)
scores_df = pd.DataFrame(scores)

scores = scores_df.merge(scores_os_df, on=['Model','Vectorizer','Min Ngram','Max Ngram'], suffixes=('_original', '_oversampled'))
scores['F1_diff'] = scores['F1_oversampled'] - scores['F1_original']
# Out:
# Reading logs from ../logs/V1
# Reading logs from ../logs/V2-1
# Reading logs from ../logs/V2
# Classifying malicious_ransomwarePOC_10min_1.log as malicious, 13383 malicious entries found
# Classifying malicious_ransomwarePOC_10min.log as malicious, 14477 malicious entries found
# Classifying malicious_JavaRansomware_30min.log as malicious, 45982 malicious entries found
# Classifying malicious_RAASNet-AES_60min.log as malicious, 10348 malicious entries found
# Classifying malicious_ransim_20min.log as malicious, 23227 malicious entries found
# Classifying malicious_RAASNet-Crypto_20min.log as malicious, 20069 malicious entries found
# Classifying malicious_roar-ChaCha20_60min.log as malicious, 33968 malicious entries found
# Classifying malicious_roar-AES-CTR_60min.log as malicious, 71676 malicious entries found
# Classifying malicious_ransim-slow_60min.log as malicious, 23621 malicious entries found
# Classifying malicious_cry_20min.log as malicious, 8185 malicious entries found
# Classifying malicious_ransim-slow_30min.log as malicious, 8586 malicious entries found
# Classifying malicious_ransim_10min.log as malicious, 3221 malicious entries found
# Classifying malicious_roar-ChaCha20_60min.log as malicious, 32965 malicious entries found
# Classifying malicious_JavaRansomware_15min.log as malicious, 15232 malicious entries found
# Classifying malicious_cry_10min.log as malicious, 4776 malicious entries found
# Classifying malicious_roar-AES-CTR_60min.log as malicious, 47470 malicious entries found
# Classifying malicious_RAASNet-Crypto_15min.log as malicious, 10145 malicious entries found
# Classifying malicious_RAASNet-AES_30min.log as malicious, 4252 malicious entries found
# Model: NB_CountVectorizer_1_1 - F1 Score: 0.8114989733059548
# Model: NB_CountVectorizer_1_1 - F1 Score: 0.8255863539445629
# Model: NB_CountVectorizer_2_2 - F1 Score: 0.9418604651162791
# Model: NB_CountVectorizer_2_2 - F1 Score: 0.9368058215243202
# Model: RF_CountVectorizer_1_1 - F1 Score: 0.9560524286815728
# Model: NB_CountVectorizer_3_3 - F1 Score: 0.9511609287429944
# Model: RF_CountVectorizer_1_1 - F1 Score: 0.9443813847900113
# Model: NB_CountVectorizer_3_3 - F1 Score: 0.9513256826276217
# Model: RF_CountVectorizer_2_2 - F1 Score: 0.9684882329477463
# Model: NB_CountVectorizer_4_4 - F1 Score: 0.9457364341085271
# Model: RF_CountVectorizer_2_2 - F1 Score: 0.9617357001972386
# Model: NB_CountVectorizer_4_4 - F1 Score: 0.9497975708502024
# Model: RF_CountVectorizer_3_3 - F1 Score: 0.9573690621193667
# Model: NB_CountVectorizer_5_5 - F1 Score: 0.9300582847626978
# Model: RF_CountVectorizer_3_3 - F1 Score: 0.9586511441188278
# Model: NB_CountVectorizer_5_5 - F1 Score: 0.9358024691358025
# Model: RF_CountVectorizer_4_4 - F1 Score: 0.9488870568837593
# Model: NB_TfidfVectorizer_1_1 - F1 Score: 0.819047619047619
# Model: RF_CountVectorizer_4_4 - F1 Score: 0.9488334015554646
# Model: NB_TfidfVectorizer_1_1 - F1 Score: 0.8142957252978276
# Model: RF_TfidfVectorizer_1_1 - F1 Score: 0.8948126801152738
# Model: RF_TfidfVectorizer_1_1 - F1 Score: 0.8947935368043088
# Model: NB_TfidfVectorizer_2_2 - F1 Score: 0.9143708116157856
# Model: NB_TfidfVectorizer_2_2 - F1 Score: 0.9109792284866469
# Model: RF_TfidfVectorizer_2_2 - F1 Score: 0.9594008671659441
# Model: RF_CountVectorizer_5_5 - F1 Score: 0.9299202685690307
# Model: RF_TfidfVectorizer_2_2 - F1 Score: 0.9590551181102362
# Model: RF_CountVectorizer_5_5 - F1 Score: 0.9333333333333333
# Model: NB_TfidfVectorizer_3_3 - F1 Score: 0.9416829745596869
# Model: NB_TfidfVectorizer_3_3 - F1 Score: 0.9387436597737027
# Model: NB_TfidfVectorizer_4_4 - F1 Score: 0.9460547504025765
# Model: NB_TfidfVectorizer_4_4 - F1 Score: 0.9456740442655935
# Model: RF_TfidfVectorizer_3_3 - F1 Score: 0.9566976932416026
# Model: RF_TfidfVectorizer_3_3 - F1 Score: 0.9566626164439044
# Model: NB_TfidfVectorizer_5_5 - F1 Score: 0.9338809034907598
# Model: NB_TfidfVectorizer_5_5 - F1 Score: 0.9347022587268994
# Model: RF_TfidfVectorizer_4_4 - F1 Score: 0.9493618773157678
# Model: RF_TfidfVectorizer_4_4 - F1 Score: 0.9472382522671063
# Model: RF_TfidfVectorizer_5_5 - F1 Score: 0.9322175732217574
# Model: RF_TfidfVectorizer_5_5 - F1 Score: 0.9299202685690307
# Model: NB_CountVectorizer_1_1 - F1 Score: 0.841648590021692
# Model: NB_CountVectorizer_2_2 - F1 Score: 0.957513768686074
# Model: NB_CountVectorizer_3_3 - F1 Score: 0.9529130087789306
# Model: NB_CountVectorizer_4_4 - F1 Score: 0.9484787018255578
# Model: RF_CountVectorizer_1_1 - F1 Score: 0.9731247492980345
# Model: NB_CountVectorizer_5_5 - F1 Score: 0.9345484672742337
# Model: RF_CountVectorizer_2_2 - F1 Score: 0.9697946033024567
# Model: NB_TfidfVectorizer_1_1 - F1 Score: 0.8522483940042827
# Model: RF_TfidfVectorizer_1_1 - F1 Score: 0.9635395329782875
# Model: NB_TfidfVectorizer_2_2 - F1 Score: 0.9225122349102773
# Model: RF_CountVectorizer_3_3 - F1 Score: 0.9583333333333334
# Model: NB_TfidfVectorizer_3_3 - F1 Score: 0.927596193628465
# Model: RF_TfidfVectorizer_2_2 - F1 Score: 0.96359918200409
# Model: NB_TfidfVectorizer_4_4 - F1 Score: 0.927487352445194
# Model: RF_CountVectorizer_4_4 - F1 Score: 0.946236559139785
# Model: NB_TfidfVectorizer_5_5 - F1 Score: 0.9294952023362536
# Model: RF_CountVectorizer_5_5 - F1 Score: 0.928
# Model: RF_TfidfVectorizer_3_3 - F1 Score: 0.9576202118989405
# Model: RF_TfidfVectorizer_4_4 - F1 Score: 0.9444904722452361
# Model: RF_TfidfVectorizer_5_5 - F1 Score: 0.9267059814658803

# %%
scores[['Model','Vectorizer','Min Ngram','F1_original', 'Model_Type_oversampled', 'F1_oversampled','F1_diff']].sort_values(by='F1_diff', ascending=False)
# Out:
#    Model       Vectorizer  Min Ngram  F1_original Model_Type_oversampled  \
# 26    NB  TfidfVectorizer          4     0.927487   Classification_SMOTE
# 27    NB  TfidfVectorizer          4     0.927487     Classification_ROS
# 22    NB  TfidfVectorizer          3     0.927596   Classification_SMOTE
# 23    NB  TfidfVectorizer          3     0.927596     Classification_ROS
# 38    RF  TfidfVectorizer          5     0.926706   Classification_SMOTE
# 33    RF  CountVectorizer          5     0.928000   Classification_SMOTE
# 31    NB  TfidfVectorizer          5     0.929495     Classification_ROS
# 36    RF  TfidfVectorizer          4     0.944490   Classification_SMOTE
# 30    NB  TfidfVectorizer          5     0.929495   Classification_SMOTE
# 39    RF  TfidfVectorizer          5     0.926706     Classification_ROS
# 37    RF  TfidfVectorizer          4     0.944490     Classification_ROS
# 28    RF  CountVectorizer          4     0.946237     Classification_ROS
# 29    RF  CountVectorizer          4     0.946237   Classification_SMOTE
# 32    RF  CountVectorizer          5     0.928000     Classification_ROS
# 7     NB  CountVectorizer          4     0.948479     Classification_ROS
# 11    NB  CountVectorizer          5     0.934548     Classification_ROS
# 21    RF  CountVectorizer          3     0.958333   Classification_SMOTE
# 34    RF  TfidfVectorizer          3     0.957620   Classification_SMOTE
# 35    RF  TfidfVectorizer          3     0.957620     Classification_ROS
# 20    RF  CountVectorizer          3     0.958333     Classification_ROS
# 12    RF  CountVectorizer          2     0.969795     Classification_ROS
# 5     NB  CountVectorizer          3     0.952913     Classification_ROS
# 4     NB  CountVectorizer          3     0.952913   Classification_SMOTE
# 6     NB  CountVectorizer          4     0.948479   Classification_SMOTE
# 24    RF  TfidfVectorizer          2     0.963599   Classification_SMOTE
# 10    NB  CountVectorizer          5     0.934548   Classification_SMOTE
# 25    RF  TfidfVectorizer          2     0.963599     Classification_ROS
# 13    RF  CountVectorizer          2     0.969795   Classification_SMOTE
# 18    NB  TfidfVectorizer          2     0.922512   Classification_SMOTE
# 19    NB  TfidfVectorizer          2     0.922512     Classification_ROS
# 2     NB  CountVectorizer          2     0.957514   Classification_SMOTE
# 1     NB  CountVectorizer          1     0.841649   Classification_SMOTE
# 8     RF  CountVectorizer          1     0.973125     Classification_ROS
# 3     NB  CountVectorizer          2     0.957514     Classification_ROS
# 9     RF  CountVectorizer          1     0.973125   Classification_SMOTE
# 0     NB  CountVectorizer          1     0.841649     Classification_ROS
# 14    NB  TfidfVectorizer          1     0.852248   Classification_SMOTE
# 15    NB  TfidfVectorizer          1     0.852248     Classification_ROS
# 16    RF  TfidfVectorizer          1     0.963540   Classification_SMOTE
# 17    RF  TfidfVectorizer          1     0.963540     Classification_ROS
#
#     F1_oversampled   F1_diff
# 26        0.946055  0.018567
# 27        0.945674  0.018187
# 22        0.941683  0.014087
# 23        0.938744  0.011147
# 38        0.932218  0.005512
# 33        0.933333  0.005333
# 31        0.934702  0.005207
# 36        0.949362  0.004871
# 30        0.933881  0.004386
# 39        0.929920  0.003214
# 37        0.947238  0.002748
# 28        0.948887  0.002650
# 29        0.948833  0.002597
# 32        0.929920  0.001920
# 7         0.949798  0.001319
# 11        0.935802  0.001254
# 21        0.958651  0.000318
# 34        0.956698 -0.000923
# 35        0.956663 -0.000958
# 20        0.957369 -0.000964
# 12        0.968488 -0.001306
# 5         0.951326 -0.001587
# 4         0.951161 -0.001752
# 6         0.945736 -0.002742
# 24        0.959401 -0.004198
# 10        0.930058 -0.004490
# 25        0.959055 -0.004544
# 13        0.961736 -0.008059
# 18        0.914371 -0.008141
# 19        0.910979 -0.011533
# 2         0.941860 -0.015653
# 1         0.825586 -0.016062
# 8         0.956052 -0.017072
# 3         0.936806 -0.020708
# 9         0.944381 -0.028743
# 0         0.811499 -0.030150
# 14        0.819048 -0.033201
# 15        0.814296 -0.037953
# 16        0.894813 -0.068727
# 17        0.894794 -0.068746
